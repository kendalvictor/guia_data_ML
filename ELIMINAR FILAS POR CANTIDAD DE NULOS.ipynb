# %%
from client import Analizer

# %%
set_parameter = {
    'sep': ',',
    'encoding': 'ISO-8859-1'
}
analizer = Analizer("data/merge_train.csv", **set_parameter)
analizer.head()
# Out:
#    Unnamed: 0  ID_SEC  TARGET_VTAMOV CODSUBSEGMENTO            PERFIL_TACTICO  \
# 0           0       1              0            X1N                    ENALTA
# 1           1       2              0            M1N                   CONSUMO
# 2           2       3              0            X1N  EXCLUSIVO ALTO POTENCIAL
# 3           3       4              0            X1N                 EXCLUSIVO
# 4           4       5              0            M1N                   CONSUMO
#
#   PERFIL_DIGITAL FLGSEXO TIPESTCIVIL TIPNIVELEDUCACIONAL TIPSITUACIONLABORAL  \
# 0        DIG MON       M         SOL                 BAC                 DEP
# 1        DIG MON       F         SOL                 LIC                 DEP
# 2        DIG MON       F         CAS                 BAC                 DEP
# 3        DIG MON       F         CAS                 BAC                 NDI
# 4        DIG MON       F         SOL                 TEC                 IND
#
# ...

# %%
analizer.null_verificator()
# Out:
#                       Nulos  Cantidad Tipo Col
# Unnamed: 0            False         0    int64
# ID_SEC                False         0    int64
# TARGET_VTAMOV         False         0    int64
# CODSUBSEGMENTO        False         0   object
# PERFIL_TACTICO         True       205   object
# PERFIL_DIGITAL        False         0   object
# FLGSEXO                True         1   object
# TIPESTCIVIL           False         0   object
# TIPNIVELEDUCACIONAL   False         0   object
# TIPSITUACIONLABORAL   False         0   object
# EDAD                  False         0    int64
# DEPARTAMENTO           True       122   object
# INGRESO_TABLA_BCAPER   True      2746  float64
# FLG_AFLUENTE           True       205  float64
# FLG_PASIVO             True       205  float64
# FLG_ACTIVO             True       205  float64
# FLG_INVERSION          True       205  float64
# FLG_PREST_PER          True       205  float64
# FLG_TC                 True       205  float64
# ...

# %%
MAX_NULL_FOR_ROW = 3
data = analizer.data.copy()
data.shape
# Out:
# (241513, 45)

# %%
"""
Lo que se realiza a continuacion es eliminar todas las filas que contengan
un numero de variables nulas superior a MAX_NULL_FOR_ROW
recordar:
sum(axis=1) indica que sumara los valores por columna
data.isnull() formara un dataframe indicando si cada elemnto presente es
              nulo o no (False, True)
"""
data_cut = data.loc[data.isnull().sum(axis=1) <= MAX_NULL_FOR_ROW]
data_cut.shape
# Out:
# (201661, 45)

# %%
analizer.data = data_cut
analizer.null_verificator()
# Out:
#                       Nulos  Cantidad Tipo Col
# Unnamed: 0            False         0    int64
# ID_SEC                False         0    int64
# TARGET_VTAMOV         False         0    int64
# CODSUBSEGMENTO        False         0   object
# PERFIL_TACTICO        False         0   object
# PERFIL_DIGITAL        False         0   object
# FLGSEXO               False         0   object
# TIPESTCIVIL           False         0   object
# TIPNIVELEDUCACIONAL   False         0   object
# TIPSITUACIONLABORAL   False         0   object
# EDAD                  False         0    int64
# DEPARTAMENTO           True        98   object
# INGRESO_TABLA_BCAPER   True       757  float64
# FLG_AFLUENTE          False         0  float64
# FLG_PASIVO            False         0  float64
# FLG_ACTIVO            False         0  float64
# FLG_INVERSION         False         0  float64
# FLG_PREST_PER         False         0  float64
# FLG_TC                False         0  float64
# ...
