# %%
#importaciones
import pandas as pd

#variables 
set_parameter = {
    'sep': ',',
    'encoding': 'ISO-8859-1',
    'low_memory': False
}

data = pd.read_csv('data/merge_train.csv', **set_parameter)
data.head(5)
# Out:
#    Unnamed: 0  ID_SEC  TARGET_VTAMOV CODSUBSEGMENTO            PERFIL_TACTICO  \
# 0           0       1              0            X1N                    ENALTA
# 1           1       2              0            M1N                   CONSUMO
# 2           2       3              0            X1N  EXCLUSIVO ALTO POTENCIAL
# 3           3       4              0            X1N                 EXCLUSIVO
# 4           4       5              0            M1N                   CONSUMO
#
#   PERFIL_DIGITAL FLGSEXO TIPESTCIVIL TIPNIVELEDUCACIONAL TIPSITUACIONLABORAL  \
# 0        DIG MON       M         SOL                 BAC                 DEP
# 1        DIG MON       F         SOL                 LIC                 DEP
# 2        DIG MON       F         CAS                 BAC                 DEP
# 3        DIG MON       F         CAS                 BAC                 NDI
# 4        DIG MON       F         SOL                 TEC                 IND
#
#        ...       RCC_D_TC RCC_D_TOTAL  TRX_VEN  TRX_HBK  TRX_BMO  TRX_DIG  \
# 0      ...       40428.78  1247875.94        6      234        8      242
# 1      ...        7905.50    27905.50        3       14        0       14
# 2      ...        4970.24     4970.24        2       13       45       58
# 3      ...       36611.01    51800.04        2        0      290      290
# 4      ...            NaN         NaN        0        0       83       83
#
#    TOTALTRX  TRX_DIG_MON  TRX_DIG_NOMON  TOTALTRX_MON
# 0       267           57            185            82
# 1        53            2             12            38
# 2        79           13             45            34
# 3       314           18            272            35
# 4        87           11             72            15
#
# [5 rows x 45 columns]

# %%
def get_memory_usage(data, deep=True):
    return '{} MB'.format(data.memory_usage(deep=deep).sum() / 1024 ** 2)

# %%
import numpy as np

def reduce_size_data(df, category=False, default=''):
    print("Tamaño de uso actual : ", get_memory_usage(df))
    print("-> Int 64 Detected")
    for col in df.select_dtypes(include=['int']).columns:
        print(" "*4, col)
        df[col] = pd.to_numeric(arg=df[col], downcast=default or'integer')
    
    print("-> Float 64 Detected")
    for col in df.select_dtypes(include=['float']).columns:
        print(" "*4, col)
        df[col] = pd.to_numeric(arg=df[col], downcast=default or'float')
    
    if category:
        for col in df.select_dtypes(include=['object']).columns:
            if len(df[col].unique()) / len(df[col]) < 0.5:
                df[col] = df[col].astype('category')
                
    print("Tamaño de uso final : ", get_memory_usage(df))                
    return df
    
data = reduce_size_data(data)
# Out:
# Tamaño de uso actual :  189.28743743896484 MB
# -> Int 64 Detected
#      Unnamed: 0
#      ID_SEC
#      TARGET_VTAMOV
#      EDAD
#      TRX_VEN
#      TRX_HBK
#      TRX_BMO
#      TRX_DIG
#      TOTALTRX
#      TRX_DIG_MON
#      TRX_DIG_NOMON
#      TOTALTRX_MON
# -> Float 64 Detected
#      INGRESO_TABLA_BCAPER
#      FLG_AFLUENTE
#      FLG_PASIVO
#      FLG_ACTIVO
#      FLG_INVERSION
#      FLG_PREST_PER
#      FLG_TC
#      FLG_HIP
#      FLG_CTASUELDO
#      FLG_CTAAHORRO
#      FLG_FFMM
#      CANT_FAMPROD
#      SALDO_PASIVO
#      SALDO_ACTIVO
#      SALDO_PASIVO_N_6M
#      SALDO_PREST_PER
#      SALDO_TC
#      SALDO_HIP
#      SALDO_CTASUELDO
#      SALDO_CTAAHORRO
#      SALDO_FFMM
#      RCC_D_VEH
#      RCC_D_HIP
#      RCC_D_TC
#      RCC_D_TOTAL
# Tamaño de uso final :  150.132230758667 MB

# %%
data
